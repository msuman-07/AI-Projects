# %% [markdown]
# <a href="https://colab.research.google.com/github/msuman-07/AI-Projects/blob/main/Housing_Dataset_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Reading the dataset
data = pd.read_csv("Housing Dataset.csv")
data
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        2      yes        no       no
# 2  12250000  9960         3          2        2      yes        no       no
# 3  12215000  7500         4          2        2      yes        no       no
# 4  11410000  7420         4          1        3      yes        no       no
# 5   1820000  3000         2          1        1      yes        no       no
# 6   1767150  2400         2          1        1      yes        no       no
# 7   1750000  3620         3          1        2      yes        no       no
# 8   1750000  2910         2          1        1      yes        no       no
# 9   1750000  3850         3          1        2      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
# !pip install pandas matplotlib seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
numerical_columns = data.select_dtypes(include=['int64', 'float64']).columns.tolist()

plt.figure(figsize=(7, 3))
for i, col in enumerate(numerical_columns[:6]):  # limit to first 6 for layout
    plt.subplot(2, 3, i + 1)
    sns.boxplot(y=data[col], color='skyblue')
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))
corr = data[numerical_columns].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Categorical columns to explore
categorical_columns = ['mainroad', 'guestroom', 'basement', 'hotwaterheating',
                       'airconditioning', 'parking', 'prefarea', 'furnishingstatus']

plt.figure(figsize=( 7, 7))
for i, col in enumerate(categorical_columns):
    plt.subplot(3, 3, i+1)
    sns.countplot(x=col, data=data, palette='Set2')
    plt.title(f'Count Plot - {col}')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-60bc4e61f245>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette='Set2')
# <ipython-input-22-60bc4e61f245>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette='Set2')
# <ipython-input-22-60bc4e61f245>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=data, palette='Set2')
# <ipython-input-22-60bc4e61f245>:8: FutureWarning:
#
# ...
